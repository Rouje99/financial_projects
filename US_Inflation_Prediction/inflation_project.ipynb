# %%
import matplotlib.pyplot as plt
from matplotlib import style

# %%
import pandas as pd

df_gdp = pd.read_csv('GDP.csv')

# %%
#GDP

df_gdp['DATE'] = df_gdp['DATE'].str[:-3]
df_gdp['DATE'] = pd.to_datetime(df_gdp['DATE'])
df_gdp.head()
# Out:
#         DATE      GDP
# 0 1947-01-01  243.164
# 1 1947-04-01  245.968
# 2 1947-07-01  249.585
# 3 1947-10-01  259.745
# 4 1948-01-01  265.742

# %%
plt.grid()
plt.plot(df_gdp['DATE'], df_gdp['GDP'])
plt.show()

# %%
# Labor Force Participation Rate

df_civpart = pd.read_csv('CIVPART.csv')
df_civpart['DATE'] = df_civpart['DATE'].str[:-3]
df_civpart['DATE'] = pd.to_datetime(df_civpart['DATE'])
df_civpart.head()
# Out:
#         DATE  CIVPART
# 0 1948-01-01     58.6
# 1 1948-02-01     58.9
# 2 1948-03-01     58.5
# 3 1948-04-01     59.0
# 4 1948-05-01     58.3

# %%
plt.grid()
plt.plot(df_civpart['DATE'], df_civpart['CIVPART'])
plt.show()

# %%
#Unemployment Rate

df_unemplyment = pd.read_csv('UNRATE.csv')
df_unemplyment['DATE'] = df_unemplyment['DATE'].str[:-3]
df_unemplyment['DATE'] = pd.to_datetime(df_unemplyment['DATE'])
df_unemplyment.head()
# Out:
#         DATE  UNRATE
# 0 1948-01-01     3.4
# 1 1948-02-01     3.8
# 2 1948-03-01     4.0
# 3 1948-04-01     3.9
# 4 1948-05-01     3.5

# %%
plt.grid()
plt.plot(df_unemplyment['DATE'], df_unemplyment['UNRATE'])
plt.show()

# %%
#Market Yield on U.S. Treasury Securities at 10-Year Constant Maturity, Quoted on an Investment Basis

df_dgs10 = pd.read_csv('DGS10.csv')
df_dgs10
print(df_dgs10.dtypes)
# Out:
# DATE     object
# DGS10    object
# dtype: object

# %%
df_dgs10['DATE'] = df_dgs10['DATE'].str[:-3]
df_dgs10['DGS10'] = pd.to_numeric(df_dgs10['DGS10'], errors='coerce')
df_dgs10.head()
# Out:
#       DATE  DGS10
# 0  1962-01   4.06
# 1  1962-01   4.03
# 2  1962-01   3.99
# 3  1962-01   4.02
# 4  1962-01   4.03

# %%
df_dgs10 = df_dgs10.groupby(['DATE']).mean()
df_dgs10 = df_dgs10.reset_index()
df_dgs10['DATE'] = pd.to_datetime(df_dgs10['DATE'])
df_dgs10.head()
# Out:
#         DATE     DGS10
# 0 1962-01-01  4.083182
# 1 1962-02-01  4.039444
# 2 1962-03-01  3.930455
# 3 1962-04-01  3.843000
# 4 1962-05-01  3.873636

# %%
plt.grid()
plt.plot(df_dgs10['DATE'], df_dgs10['DGS10'])
plt.show()

# %%
#M2

df_m2 = pd.read_csv('M2SL.csv')
df_m2['DATE'] = df_m2['DATE'].str[:-3]
df_m2['DATE'] = pd.to_datetime(df_m2['DATE'])
df_m2.head()
# Out:
#         DATE   M2SL
# 0 1959-01-01  286.6
# 1 1959-02-01  287.7
# 2 1959-03-01  289.2
# 3 1959-04-01  290.1
# 4 1959-05-01  292.2

# %%
plt.grid()
plt.plot(df_m2['DATE'], df_m2['M2SL'])
plt.show()

# %%
#Federal Funds Effective Rate

df_fed = pd.read_csv('FEDFUNDS.csv')
df_fed['DATE'] = df_fed['DATE'].str[:-3]
df_fed['DATE'] = pd.to_datetime(df_fed['DATE'])
df_fed.head()
# Out:
#         DATE  FEDFUNDS
# 0 1954-07-01      0.80
# 1 1954-08-01      1.22
# 2 1954-09-01      1.07
# 3 1954-10-01      0.85
# 4 1954-11-01      0.83

# %%
plt.grid()
plt.plot(df_fed['DATE'], df_fed['FEDFUNDS'])
plt.show()

# %%
#All Employees, Total Nonfarm

df_payems = pd.read_csv('PAYEMS.csv')
df_payems['DATE'] = df_payems['DATE'].str[:-3]
df_payems['DATE'] = pd.to_datetime(df_payems['DATE'])
df_payems.head()
# Out:
#         DATE  PAYEMS
# 0 1939-01-01   29923
# 1 1939-02-01   30100
# 2 1939-03-01   30280
# 3 1939-04-01   30094
# 4 1939-05-01   30299

# %%
plt.grid()
plt.plot(df_payems['DATE'], df_payems['PAYEMS'])
plt.show()

# %%
#Inflation, consumer prices for the United States

df_inflation = pd.read_csv('FPCPITOTLZGUSA.csv')
df_inflation['DATE'] = df_inflation['DATE'].str[:-3]
df_inflation['DATE'] = pd.to_datetime(df_inflation['DATE'])
df_inflation.head()
# Out:
#         DATE  FPCPITOTLZGUSA
# 0 1960-01-01        1.457976
# 1 1961-01-01        1.070724
# 2 1962-01-01        1.198773
# 3 1963-01-01        1.239669
# 4 1964-01-01        1.278912

# %%
plt.grid()
plt.plot(df_inflation['DATE'], df_inflation['FPCPITOTLZGUSA'])
plt.show()

# %%
df_ = pd.read_csv('7fd7f39a-6794-4184-ad1c-055cd5f1e9a9_Data.csv')
df_.head()
# Out:
#     Country Name Country Code  \
# 0  United States          USA
# 1  United States          USA
# 2  United States          USA
# 3            NaN          NaN
# 4            NaN          NaN
#
#                                          Series Name     Series Code  \
# 0              Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG
# 1              Energy imports, net (% of energy use)  EG.IMP.CONS.ZS
# 2  Renewable energy consumption (% of total final...  EG.FEC.RNEW.ZS
# 3                                                NaN             NaN
# 4                                                NaN             NaN
#
#       1960 [YR1960]     1961 [YR1961]     1962 [YR1962]     1963 [YR1963]  \
# 0  1.45797598627786  1.07072414764723  1.19877334820185   1.2396694214876
# 1  5.34081618748347  5.57885796797174  5.82595283059258  6.23887607972911
# 2                ..                ..                ..                ..
# ...

# %%
df_energyimport = df_.iloc[2][4:-1]
import numpy as np
df_energyimport = df_energyimport.replace("..", np.nan)
df_energyimport = df_energyimport.to_frame(name="Energy_import")

# %%
l = []
for i in range(1960,2022):
    a = (str(i) + '-01')
    l.append(a)
df_energyimport['DATE'] = l

# %%
df_energyimport['DATE'] = pd.to_datetime(df_energyimport['DATE'])

# %%
df_energyimport = df_energyimport.reset_index()
df_energyimport.head()
# Out:
#            index Energy_import       DATE
# 0  1960 [YR1960]           NaN 1960-01-01
# 1  1961 [YR1961]           NaN 1961-01-01
# 2  1962 [YR1962]           NaN 1962-01-01
# 3  1963 [YR1963]           NaN 1963-01-01
# 4  1964 [YR1964]           NaN 1964-01-01

# %%
df_energyimport.drop(columns=['index'])
# Out:
#    Energy_import       DATE
# 0            NaN 1960-01-01
# 1            NaN 1961-01-01
# 2            NaN 1962-01-01
# 3            NaN 1963-01-01
# 4            NaN 1964-01-01
# ..           ...        ...
# 57          9.92 2017-01-01
# 58         10.12 2018-01-01
# 59         10.42 2019-01-01
# 60           NaN 2020-01-01
# 61           NaN 2021-01-01
#
# [62 rows x 2 columns]

# %%
df_energyimport = df_energyimport[['DATE', 'Energy_import']]

# %%
plt.grid()
plt.plot(df_energyimport['DATE'], df_energyimport['Energy_import'])
plt.show()

# %%
df_house = pd.read_csv('CSUSHPINSA.csv')
df_house['DATE'] = df_house['DATE'].str[:-3]
df_house['DATE'] = pd.to_datetime(df_house['DATE'])
df_house.head()
# Out:
#         DATE  CSUSHPINSA
# 0 1987-01-01      63.735
# 1 1987-02-01      64.134
# 2 1987-03-01      64.469
# 3 1987-04-01      64.973
# 4 1987-05-01      65.547

# %%
plt.grid()
plt.plot(df_house['DATE'], df_house['CSUSHPINSA'])
plt.show()

# %%
df_list = [df_gdp, df_civpart, df_dgs10, df_m2,df_house, df_fed, df_payems,df_energyimport, df_unemplyment,df_inflation]

# %%
df = df_list[0]
for df_ in df_list[1:]:
    df = df.merge(df_, on='DATE', how = 'left')

# %%
df
# Out:
#           DATE        GDP  CIVPART   DGS10     M2SL  CSUSHPINSA  FEDFUNDS  \
# 0   1947-01-01    243.164      NaN     NaN      NaN         NaN       NaN
# 1   1947-04-01    245.968      NaN     NaN      NaN         NaN       NaN
# 2   1947-07-01    249.585      NaN     NaN      NaN         NaN       NaN
# 3   1947-10-01    259.745      NaN     NaN      NaN         NaN       NaN
# 4   1948-01-01    265.742     58.6     NaN      NaN         NaN       NaN
# ..         ...        ...      ...     ...      ...         ...       ...
# 299 2021-10-01  24349.121     61.8  1.5825  21143.8     273.692      0.08
# 300 2022-01-01  24740.480     62.2  1.7640  21649.7     282.009      0.08
# 301 2022-04-01  25248.476     62.2  2.7475  21644.2     301.805      0.33
# 302 2022-07-01  25723.941     62.1  2.8960  21636.1     307.164      1.68
# 303 2022-10-01  26132.458     62.2  3.9835  21415.5     298.958      3.08
#
#      PAYEMS Energy_import  UNRATE  FPCPITOTLZGUSA
# ...

# %%
for j in df.columns:
    for i in reversed(range(len(df['DATE'])-1)):
        if pd.isna(df[j][i]):
            df[j][i] = df[j][i+1]
# Out:
# C:\Users\rouje99\AppData\Local\Temp\ipykernel_11956\1074503824.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[j][i] = df[j][i+1]

# %%
df = df[df['DATE'] >= "1987-01-01"]

# %%
df = df.reset_index()

# %%
for j in df.columns:
    for i in range(len(df['DATE'])):
        if pd.isna(df[j][i]) and j == "FPCPITOTLZGUSA":
            df[j][i] = df[j][i-1]
        
for j in df.columns:
    for i in range(len(df['DATE'])):
        if pd.isna(df[j][i]) and j == "Energy_import":
            df[j][i] = df[j][i-1]
# Out:
# C:\Users\rouje99\AppData\Local\Temp\ipykernel_11956\2104742288.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[j][i] = df[j][i-1]

# %%
df = df[:-9]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 295 entries, 0 to 294
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   index           295 non-null    int64
#  1   DATE            295 non-null    datetime64[ns]
#  2   GDP             295 non-null    float64
#  3   CIVPART         295 non-null    float64
#  4   DGS10           295 non-null    float64
#  5   M2SL            295 non-null    float64
#  6   CSUSHPINSA      295 non-null    float64
#  7   FEDFUNDS        295 non-null    float64
#  8   PAYEMS          295 non-null    int64
#  9   Energy_import   295 non-null    object
#  10  UNRATE          295 non-null    float64
#  11  FPCPITOTLZGUSA  295 non-null    float64
# dtypes: datetime64[ns](1), float64(8), int64(2), object(1)
# memory usage: 27.8+ KB

# %%
df = df.drop(columns="index")

# %%
df = df.set_index("DATE")

# %%
df['Energy_import'] = pd.to_numeric(df['Energy_import'])

# %%
import seaborn as sns
corr_df = df.corr(method='pearson')
plt.figure(figsize=(10, 10))
heatmap = sns.heatmap(corr_df, annot=True)
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':12}, pad=12)
plt.show()

# %%
df_X = df.drop(columns='FPCPITOTLZGUSA')

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df_X = scaler.fit_transform(df_X)

# %%
# Check where correlation among features is > 0.9
corr = df.corr()
high_corr = (corr >= 0.90).astype('uint8')
plt.figure(figsize=(15,15))
sns.heatmap(high_corr, cmap='RdBu_r', annot=True, center=0.0)
plt.show()

# %%
#Linear Regression

from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
X_train, X_test, Y_train, Y_test = train_test_split(df_X,df['FPCPITOTLZGUSA'], test_size = 0.2 )

# %%
clf = LinearRegression()
clf.fit(X_train, Y_train)
accuracy = clf.score(X_test, Y_test)
print (accuracy)
# Out:
# 0.6860632948937013

# %%
X_new = df_X[-50:]
prediction = clf.predict(X_new)

# %%
#prediction of the next 100 days
plt.plot(df.index[-50:], df['FPCPITOTLZGUSA'][-50:], 'b' )
plt.plot(df.index[-50:], prediction, 'r' )
plt.show()

# %%
#SVM

from sklearn import svm
regr = svm.SVR()

# %%
regr.fit(X_train, Y_train)
# Out:
# SVR()

# %%
regr.score(X_test,Y_test)
# Out:
# 0.6797244905519595

# %%
regr.get_params()
# Out:
# {'C': 1.0,
#  'cache_size': 200,
#  'coef0': 0.0,
#  'degree': 3,
#  'epsilon': 0.1,
#  'gamma': 'scale',
#  'kernel': 'rbf',
#  'max_iter': -1,
#  'shrinking': True,
#  'tol': 0.001,
#  'verbose': False}

# %%
pred = regr.predict(df_X[-50:])

# %%
plt.plot(df.index[-50:], df['FPCPITOTLZGUSA'][-50:], 'b' )
plt.plot(df.index[-50:], pred, 'r' )
plt.show()

# %%
#Decision Tree

from sklearn.tree import DecisionTreeRegressor

# %%
regr_1 = DecisionTreeRegressor(max_depth=2)
regr_2 = DecisionTreeRegressor(max_depth=5)
regr_3 = DecisionTreeRegressor(max_depth=20)

# %%
regr_1.fit(X_train, Y_train)
regr_2.fit(X_train, Y_train)
regr_3.fit(X_train, Y_train)
# Out:
# DecisionTreeRegressor(max_depth=20)

# %%
y_1 = regr_1.predict(df_X[-50:])
y_2 = regr_2.predict(df_X[-50:])
y_3= regr_3.predict(df_X[-50:])

# %%
plt.plot(df.index[-50:], df['FPCPITOTLZGUSA'][-50:], 'b' )
plt.plot(df.index[-50:], y_1, 'r' )
plt.show()

print(regr_1.score(X_train,Y_train))
# Out:
# 0.7154377024735414

# %%
plt.plot(df.index[-50:], df['FPCPITOTLZGUSA'][-50:], 'b' )
plt.plot(df.index[-50:], y_2, 'r' )
plt.show()

print(regr_2.score(X_train,Y_train))
# Out:
# 0.9643655003340791

# %%
plt.plot(df.index[-50:], df['FPCPITOTLZGUSA'][-50:], 'b' )
plt.plot(df.index[-50:], y_3, 'r' )
plt.show()

print(regr_3.score(X_train,Y_train))
# Out:
# 1.0
